# %%
from statsmodels.tsa.stattools import adfuller
import pandas as pd
import numpy as np
# %matplotlib inline
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt

# %%
#Data Cleaning: Proof Type- POW

# %%
bch = pd.read_csv(r'C:\Users\ASUS\Desktop\daydata\daydata_BCH')

# %%
bch
# Out:
#         datetime     low     high    open   close  volumefrom      volumeto
# 0     2017-08-01  238.00   479.90  501.69  441.72    57843.14  2.555024e+07
# 1     2017-08-02  388.76  1152.69  441.72  670.61   304216.78  2.040110e+08
# 2     2017-08-03  374.01   803.38  670.61  405.76   233260.03  9.464819e+07
# 3     2017-08-04  217.04   418.82  405.76  217.27   388074.60  8.431636e+07
# 4     2017-08-05  191.23   283.67  217.27  203.50   380669.95  7.746665e+07
# ...          ...     ...      ...     ...     ...         ...           ...
# 1604  2021-12-22  434.03   443.66  437.96  438.02    70862.56  3.103928e+07
# 1605  2021-12-23  453.20   464.03  438.02  455.69    64731.89  2.949785e+07
# 1606  2021-12-24  449.26   461.34  455.61  451.98    29890.90  1.363662e+07
# 1607  2021-12-25  446.22   455.75  452.38  455.35    40900.02  1.862371e+07
# 1608  2021-12-26  445.04   455.60  455.55  449.90    10075.95  4.525115e+06
#
# [1609 rows x 7 columns]

# %%
bch.rename({'close':'bitcoin'}, axis=1, inplace=True)
bch
# Out:
#         datetime     low     high    open  bitcoin  volumefrom      volumeto
# 0     2017-08-01  238.00   479.90  501.69   441.72    57843.14  2.555024e+07
# 1     2017-08-02  388.76  1152.69  441.72   670.61   304216.78  2.040110e+08
# 2     2017-08-03  374.01   803.38  670.61   405.76   233260.03  9.464819e+07
# 3     2017-08-04  217.04   418.82  405.76   217.27   388074.60  8.431636e+07
# 4     2017-08-05  191.23   283.67  217.27   203.50   380669.95  7.746665e+07
# ...          ...     ...      ...     ...      ...         ...           ...
# 1604  2021-12-22  434.03   443.66  437.96   438.02    70862.56  3.103928e+07
# 1605  2021-12-23  453.20   464.03  438.02   455.69    64731.89  2.949785e+07
# 1606  2021-12-24  449.26   461.34  455.61   451.98    29890.90  1.363662e+07
# 1607  2021-12-25  446.22   455.75  452.38   455.35    40900.02  1.862371e+07
# 1608  2021-12-26  445.04   455.60  455.55   449.90    10075.95  4.525115e+06
#
# [1609 rows x 7 columns]

# %%
btc = pd.read_csv(r'C:\Users\ASUS\Desktop\daydata\daydata_BTC')

# %%
btc.rename({'close':'bitcoin_cash'}, axis=1, inplace=True)
btc
# Out:
#         datetime       low      high      open  bitcoin_cash  volumefrom  \
# 0     2016-07-05    657.31    679.19    675.16        663.67    54642.80
# 1     2016-07-06    662.24    678.39    663.67        672.70    47049.50
# 2     2016-07-07    604.95    676.19    672.70        635.25   153608.21
# 3     2016-07-08    630.17    663.43    635.25        662.78    75892.55
# 4     2016-07-09    620.68    663.49    662.78        651.83    96013.13
# ...          ...       ...       ...       ...           ...         ...
# 1996  2021-12-22  48460.43  49581.41  48917.48      48614.97    20998.03
# 1997  2021-12-23  48062.25  51382.88  48614.97      50830.20    30734.43
# 1998  2021-12-24  50449.36  51863.56  50830.20      50840.36    21669.58
# 1999  2021-12-25  50199.56  51158.56  50840.36      50431.63    11532.27
# 2000  2021-12-26  49485.62  50696.78  50431.63      49861.38     7414.79
#
#           volumeto
# 0     3.668726e+07
# 1     3.170810e+07
# 2     9.763934e+07
# 3     4.924301e+07
# 4     6.206121e+07
# ...            ...
# 1996  1.028435e+09
# 1997  1.525047e+09
# 1998  1.107245e+09
# 1999  5.858190e+08
# 2000  3.706464e+08
#
# [2001 rows x 7 columns]

# %%
bitcoinSV = pd.read_csv(r'C:\Users\ASUS\Desktop\daydata\daydata_BSV(bitcoinSV)')

# %%
bitcoinSV.rename({'close':'bitcoinSV'}, axis=1, inplace=True)
bitcoinSV
# Out:
#         datetime     low    high    open  bitcoinSV  volumefrom     volumeto
# 0     2018-11-19   65.20   72.90   71.00      70.00      320.75     22546.88
# 1     2018-11-20   47.22   61.52   66.28      51.61   612997.52  31639151.14
# 2     2018-11-21   50.34   56.45   51.75      52.41   252471.83  13231186.77
# 3     2018-11-22   41.23   50.64   52.41      42.72   222525.78   9506943.05
# 4     2018-11-23   38.04   63.59   42.74      54.73   673596.53  36863979.27
# ...          ...     ...     ...     ...        ...         ...          ...
# 1129  2021-12-22  122.46  125.04  124.54     123.77   114851.00  14215534.78
# 1130  2021-12-23  127.28  130.94  123.77     129.46   116329.96  15060602.36
# 1131  2021-12-24  126.80  131.22  129.46     129.34   111039.27  14361583.32
# 1132  2021-12-25  126.94  129.21  129.34     128.25   113599.59  14568878.76
# 1133  2021-12-26  124.80  129.12  128.25     126.62    45807.26   5800265.79
#
# [1134 rows x 7 columns]

# %%
eth = pd.read_csv(r'C:\Users\ASUS\Desktop\daydata\daydata_ETH')
eth
# Out:
#         datetime       low     high     open    close  volumefrom  \
# 0     2016-07-05     8.976    11.41    11.34    10.45   644840.11
# 1     2016-07-06    10.210    11.11    10.47    10.43  1180583.52
# 2     2016-07-07     9.529    10.31    10.43    10.03  1068420.96
# 3     2016-07-08    10.300    11.64    10.03    11.27  1075333.09
# 4     2016-07-09    10.690    11.34    11.27    10.92  1004312.60
# ...          ...       ...      ...      ...      ...         ...
# 1996  2021-12-22  3940.860  4075.00  4017.70  3981.26   191823.84
# 1997  2021-12-23  3896.440  4155.17  3981.26  4112.35   315272.64
# 1998  2021-12-24  4014.980  4137.22  4112.35  4047.87   179378.39
# 1999  2021-12-25  4023.500  4141.62  4047.87  4097.06   108759.92
# 2000  2021-12-26  4008.080  4105.58  4097.06  4045.31    57232.42
#
#           volumeto
# 0     6.584753e+06
# 1     1.230977e+07
# 2     1.071690e+07
# 3     1.211606e+07
# 4     1.097178e+07
# ...            ...
# 1996  7.691847e+08
# 1997  1.268270e+09
# 1998  7.330022e+08
# 1999  4.433175e+08
# 2000  2.316460e+08
#
# [2001 rows x 7 columns]

# %%
eth.rename({'close':'eth'}, axis=1, inplace=True)
eth
# Out:
#         datetime       low     high     open      eth  volumefrom  \
# 0     2016-07-05     8.976    11.41    11.34    10.45   644840.11
# 1     2016-07-06    10.210    11.11    10.47    10.43  1180583.52
# 2     2016-07-07     9.529    10.31    10.43    10.03  1068420.96
# 3     2016-07-08    10.300    11.64    10.03    11.27  1075333.09
# 4     2016-07-09    10.690    11.34    11.27    10.92  1004312.60
# ...          ...       ...      ...      ...      ...         ...
# 1996  2021-12-22  3940.860  4075.00  4017.70  3981.26   191823.84
# 1997  2021-12-23  3896.440  4155.17  3981.26  4112.35   315272.64
# 1998  2021-12-24  4014.980  4137.22  4112.35  4047.87   179378.39
# 1999  2021-12-25  4023.500  4141.62  4047.87  4097.06   108759.92
# 2000  2021-12-26  4008.080  4105.58  4097.06  4045.31    57232.42
#
#           volumeto
# 0     6.584753e+06
# 1     1.230977e+07
# 2     1.071690e+07
# 3     1.211606e+07
# 4     1.097178e+07
# ...            ...
# 1996  7.691847e+08
# 1997  1.268270e+09
# 1998  7.330022e+08
# 1999  4.433175e+08
# 2000  2.316460e+08
#
# [2001 rows x 7 columns]

# %%
ltc = pd.read_csv(r'C:\Users\ASUS\Desktop\daydata\daydata_LTC')

# %%
ltc.rename({'close':'ltc'}, axis=1, inplace=True)
ltc
# Out:
#         datetime      low     high     open      ltc  volumefrom     volumeto
# 0     2016-07-05    4.239    4.501    4.456    4.364   126599.10    552987.93
# 1     2016-07-06    4.377    4.482    4.364    4.428    53064.32    235769.85
# 2     2016-07-07    3.838    4.446    4.428    4.069   424760.78   1734843.68
# 3     2016-07-08    3.976    4.211    4.069    4.180   151763.40    624521.43
# 4     2016-07-09    3.900    4.205    4.180    4.121   193156.89    782078.63
# ...          ...      ...      ...      ...      ...         ...          ...
# 1996  2021-12-22  153.050  160.180  154.800  155.440   398747.80  62478507.84
# 1997  2021-12-23  153.100  165.160  155.440  163.670   505529.28  80230428.49
# 1998  2021-12-24  160.350  166.750  163.670  161.250   358227.15  58607317.13
# 1999  2021-12-25  157.700  163.680  161.250  157.770   295525.74  47651507.63
# 2000  2021-12-26  153.250  158.450  157.770  155.160   243042.12  37902576.16
#
# [2001 rows x 7 columns]

# %%
minota = pd.read_csv(r'C:\Users\ASUS\Desktop\daydata\daydata_MIOTA')

# %%
minota.rename({'close':'minota'}, axis=1, inplace=True)
minota
# Out:
#         datetime     low    high    open  minota  volumefrom    volumeto
# 0     2017-06-13  0.5380  0.5890  0.5530  0.5870   161426.23    89085.41
# 1     2017-06-14  0.4795  0.6101  0.5870  0.5202  7801447.35  4352877.46
# 2     2017-06-15  0.2912  0.5447  0.5202  0.3467  7001897.70  2693369.33
# 3     2017-06-16  0.3053  0.5990  0.3467  0.4082  4599676.22  1857604.87
# 4     2017-06-17  0.4000  0.4512  0.4082  0.4280  1422734.77   622794.30
# ...          ...     ...     ...     ...     ...         ...         ...
# 1653  2021-12-22  1.2590  1.3410  1.3180  1.2750  6748347.24  8761919.08
# 1654  2021-12-23  1.2300  1.3170  1.2750  1.2970  3019761.68  3845587.57
# 1655  2021-12-24  1.2570  1.3230  1.2970  1.2840  2320212.81  2992504.64
# 1656  2021-12-25  1.2730  1.3780  1.2840  1.3240  4025665.78  5409850.63
# 1657  2021-12-26  1.2830  1.3670  1.3240  1.3530  1171518.24  1559288.46
#
# [1658 rows x 7 columns]

# %%
monero = pd.read_csv(r'C:\Users\ASUS\Desktop\daydata\daydata_XMR(monero)')

# %%
monero.rename({'close':'monero'}, axis=1, inplace=True)
monero
# Out:
#         datetime      low     high     open   monero  volumefrom     volumeto
# 0     2016-07-05    1.619    1.726    1.690    1.710    86819.93    148486.18
# 1     2016-07-06    1.723    1.974    1.710    1.972   246468.05    485957.04
# 2     2016-07-07    1.763    2.091    1.972    1.885   791050.96   1490962.37
# 3     2016-07-08    1.887    2.059    1.885    1.953   211859.00    413665.27
# 4     2016-07-09    1.863    2.001    1.953    1.950   159090.15    310269.60
# ...          ...      ...      ...      ...      ...         ...          ...
# 1996  2021-12-22  186.050  193.680  189.020  190.670   190621.51  36345405.36
# 1997  2021-12-23  198.090  224.420  190.670  209.780   295435.69  61975386.85
# 1998  2021-12-24  201.840  210.020  209.780  204.330   151799.47  31016792.06
# 1999  2021-12-25  202.130  216.910  204.330  211.010   119788.35  25276053.38
# 2000  2021-12-26  206.230  211.880  211.150  207.640    14185.27   2963527.22
#
# [2001 rows x 7 columns]

# %%
etc = pd.read_csv(r'C:\Users\ASUS\Desktop\daydata\daydata_ETC')

# %%
etc.rename({'close':'etc'}, axis=1, inplace=True)
etc
# Out:
#         datetime      low    high     open      etc  volumefrom     volumeto
# 0     2016-07-24   0.1263   6.315   7.2000   0.9094  2272097.01   2066154.14
# 1     2016-07-25   0.4540   1.026   0.9094   0.6301  1051419.77    662536.61
# 2     2016-07-26   0.5078   3.624   0.6301   2.5490  5270908.34  13434912.85
# 3     2016-07-27   1.0000   2.300   2.2000   1.6000   361910.20    558826.04
# 4     2016-07-28   1.3600   2.110   1.6000   1.6770   890279.17   1528481.27
# ...          ...      ...     ...      ...      ...         ...          ...
# 1977  2021-12-22  35.1800  36.480  35.3300  35.6700   129240.44   4643267.18
# 1978  2021-12-23  35.1800  37.700  35.6700  37.5600   155663.27   5680781.18
# 1979  2021-12-24  37.0100  38.470  37.5600  37.4000   148906.04   5631207.57
# 1980  2021-12-25  37.2400  38.760  37.4000  38.1100    81088.32   3087026.17
# 1981  2021-12-26  37.0100  38.280  38.1100  37.4100    47799.88   1789206.37
#
# [1982 rows x 7 columns]

# %%
#Data Merging

# %%
#Proof Type-POW

# %%
pow = pd.merge(btc, bch,
                  left_on='datetime', right_on='datetime')

# %%
pow1 = pd.merge(pow, bitcoinSV,
                  left_on='datetime', right_on='datetime')

# %%
pow2 = pd.merge(pow1, eth,
                  left_on='datetime', right_on='datetime')

# %%
pow3 = pd.merge(pow2, ltc,
                  left_on='datetime', right_on='datetime')

# %%
pow4 = pd.merge(pow3, minota,
                  left_on='datetime', right_on='datetime')

# %%
pow5 = pd.merge(pow4, monero,
                  left_on='datetime', right_on='datetime')

# %%
pow6 = pd.merge(pow5, etc,
                  left_on='datetime', right_on='datetime')

# %%
pow6
# Out:
#         datetime     low_x    high_x    open_x  bitcoin_cash  volumefrom_x  \
# 0     2018-11-19   4757.01   5615.98   5615.26       4809.62     207964.38
# 1     2018-11-20   4168.25   4953.56   4809.62       4441.81     315023.21
# 2     2018-11-21   4315.58   4689.55   4441.81       4593.04     152286.19
# 3     2018-11-22   4297.21   4640.72   4593.04       4320.68      83715.43
# 4     2018-11-23   4157.19   4419.48   4320.68       4343.42     121719.16
# ...          ...       ...       ...       ...           ...           ...
# 1129  2021-12-22  48460.43  49581.41  48917.48      48614.97      20998.03
# 1130  2021-12-23  48062.25  51382.88  48614.97      50830.20      30734.43
# 1131  2021-12-24  50449.36  51863.56  50830.20      50840.36      21669.58
# 1132  2021-12-25  50199.56  51158.56  50840.36      50431.63      11532.27
# 1133  2021-12-26  49485.62  50696.78  50431.63      49861.38       7414.79
#
#         volumeto_x   low_y  high_y  open_y  ...  open_y  monero_y  \
# 0     1.072038e+09  213.44  286.06  333.79  ...   89.39     72.10
# 1     1.433401e+09  190.88  226.18  225.29  ...   72.10     66.05
# 2     6.862849e+08  154.24  251.16  219.64  ...   66.05     68.62
# 3     3.768528e+08  177.26  222.20  241.61  ...   68.62     65.29
# 4     5.218260e+08  138.17  180.12  178.51  ...   65.29     66.63
# ...            ...     ...     ...     ...  ...     ...       ...
# 1129  1.028435e+09  434.03  443.66  437.96  ...  189.02    190.67
# 1130  1.525047e+09  453.20  464.03  438.02  ...  190.67    209.78
# 1131  1.107245e+09  449.26  461.34  455.61  ...  209.78    204.33
# 1132  5.858190e+08  446.22  455.75  452.38  ...  204.33    211.01
# 1133  3.706464e+08  445.04  455.60  455.55  ...  211.15    207.64
#
#       volumefrom_y   volumeto_y    low   high   open    etc  volumefrom  \
# 0        205390.39  14807867.42   6.13   7.47   7.47   6.21  2698649.58
# 1        200644.65  13252521.89   5.12   6.48   6.21   5.58  4662165.11
# 2        167461.01  11491177.45   5.36   5.96   5.58   5.78  1230577.75
# 3        109712.67   7162643.75   5.23   5.83   5.78   5.24   690539.33
# 4        121159.20   8072602.79   4.99   5.38   5.24   5.22  1166110.74
# ...            ...          ...    ...    ...    ...    ...         ...
# 1129     190621.51  36345405.36  35.18  36.48  35.33  35.67   129240.44
# 1130     295435.69  61975386.85  35.18  37.70  35.67  37.56   155663.27
# 1131     151799.47  31016792.06  37.01  38.47  37.56  37.40   148906.04
# 1132     119788.35  25276053.38  37.24  38.76  37.40  38.11    81088.32
# 1133      14185.27   2963527.22  37.01  38.28  38.11  37.41    47799.88
#
#          volumeto
# 0     17653571.63
# 1     27005524.81
# 2      6947264.97
# 3      3866868.19
# 4      6016252.93
# ...           ...
# 1129   4643267.18
# 1130   5680781.18
# 1131   5631207.57
# 1132   3087026.17
# 1133   1789206.37
#
# [1134 rows x 91 columns]

# %%
pow6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1134 entries, 0 to 1133
# Data columns (total 91 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datetime      1134 non-null   object
#  1   low_x         1134 non-null   float64
#  2   high_x        1134 non-null   float64
#  3   open_x        1134 non-null   float64
#  4   bitcoin_cash  1134 non-null   float64
#  5   volumefrom_x  1134 non-null   float64
#  6   volumeto_x    1134 non-null   float64
#  7   low_y         1134 non-null   float64
#  8   high_y        1134 non-null   float64
#  9   open_y        1134 non-null   float64
#  10  bitcoin       1134 non-null   float64
#  11  volumefrom_y  1134 non-null   float64
#  12  volumeto_y    1134 non-null   float64
#  13  low_x         1134 non-null   float64
#  14  high_x        1134 non-null   float64
#  15  open_x        1134 non-null   float64
#  16  bitcoinSV_x   1134 non-null   float64
#  17  volumefrom_x  1134 non-null   float64
#  18  volumeto_x    1134 non-null   float64
#  19  low_y         1134 non-null   float64
#  20  high_y        1134 non-null   float64
#  21  open_y        1134 non-null   float64
#  22  eth_x         1134 non-null   float64
#  23  volumefrom_y  1134 non-null   float64
#  24  volumeto_y    1134 non-null   float64
#  25  low_x         1134 non-null   float64
#  26  high_x        1134 non-null   float64
#  27  open_x        1134 non-null   float64
#  28  ltc_x         1134 non-null   float64
#  29  volumefrom_x  1134 non-null   float64
#  30  volumeto_x    1134 non-null   float64
#  31  low_y         1134 non-null   float64
#  32  high_y        1134 non-null   float64
#  33  open_y        1134 non-null   float64
#  34  minota_x      1134 non-null   float64
#  35  volumefrom_y  1134 non-null   float64
#  36  volumeto_y    1134 non-null   float64
#  37  low_x         1134 non-null   float64
#  38  high_x        1134 non-null   float64
#  39  open_x        1134 non-null   float64
#  40  monero_x      1134 non-null   float64
#  41  volumefrom_x  1134 non-null   float64
#  42  volumeto_x    1134 non-null   float64
#  43  low_y         1134 non-null   float64
#  44  high_y        1134 non-null   float64
#  45  open_y        1134 non-null   float64
#  46  etc_x         1134 non-null   float64
#  47  volumefrom_y  1134 non-null   float64
#  48  volumeto_y    1134 non-null   float64
#  49  low_x         1134 non-null   float64
#  50  high_x        1134 non-null   float64
#  51  open_x        1134 non-null   float64
#  52  etc_y         1134 non-null   float64
#  53  volumefrom_x  1134 non-null   float64
#  54  volumeto_x    1134 non-null   float64
#  55  low_y         1134 non-null   float64
#  56  high_y        1134 non-null   float64
#  57  open_y        1134 non-null   float64
#  58  bitcoinSV_y   1134 non-null   float64
#  59  volumefrom_y  1134 non-null   float64
#  60  volumeto_y    1134 non-null   float64
#  61  low_x         1134 non-null   float64
#  62  high_x        1134 non-null   float64
#  63  open_x        1134 non-null   float64
#  64  eth_y         1134 non-null   float64
#  65  volumefrom_x  1134 non-null   float64
#  66  volumeto_x    1134 non-null   float64
#  67  low_y         1134 non-null   float64
#  68  high_y        1134 non-null   float64
#  69  open_y        1134 non-null   float64
#  70  ltc_y         1134 non-null   float64
#  71  volumefrom_y  1134 non-null   float64
#  72  volumeto_y    1134 non-null   float64
#  73  low_x         1134 non-null   float64
#  74  high_x        1134 non-null   float64
#  75  open_x        1134 non-null   float64
#  76  minota_y      1134 non-null   float64
#  77  volumefrom_x  1134 non-null   float64
#  78  volumeto_x    1134 non-null   float64
#  79  low_y         1134 non-null   float64
#  80  high_y        1134 non-null   float64
#  81  open_y        1134 non-null   float64
#  82  monero_y      1134 non-null   float64
#  83  volumefrom_y  1134 non-null   float64
#  84  volumeto_y    1134 non-null   float64
#  85  low           1134 non-null   float64
#  86  high          1134 non-null   float64
#  87  open          1134 non-null   float64
#  88  etc           1134 non-null   float64
#  89  volumefrom    1134 non-null   float64
#  90  volumeto      1134 non-null   float64
# dtypes: float64(90), object(1)
# memory usage: 815.1+ KB

# %%
pow = pow6.loc[:, ['datetime', 'bitcoin', 'bitcoinSV_x', 'bitcoin_cash', 'eth_y', 'ltc_y', 'minota_y', 'monero_y', 'etc']]
pow
# Out:
#         datetime  bitcoin  bitcoinSV_x  bitcoin_cash    eth_y   ltc_y  \
# 0     2018-11-19   225.29        70.00       4809.62   148.22   36.30
# 1     2018-11-20   218.34        51.61       4441.81   130.74   32.84
# 2     2018-11-21   241.61        52.41       4593.04   136.50   34.63
# 3     2018-11-22   178.51        42.72       4320.68   125.08   31.74
# 4     2018-11-23   140.64        54.73       4343.42   123.37   32.20
# ...          ...      ...          ...           ...      ...     ...
# 1129  2021-12-22   438.02       123.77      48614.97  3981.26  155.44
# 1130  2021-12-23   455.69       129.46      50830.20  4112.35  163.67
# 1131  2021-12-24   451.98       129.34      50840.36  4047.87  161.25
# 1132  2021-12-25   455.35       128.25      50431.63  4097.06  157.77
# 1133  2021-12-26   449.90       126.62      49861.38  4045.31  155.16
#
#       minota_y  monero_y    etc
# 0       0.3552     72.10   6.21
# 1       0.3046     66.05   5.58
# 2       0.3323     68.62   5.78
# 3       0.3040     65.29   5.24
# 4       0.3207     66.63   5.22
# ...        ...       ...    ...
# 1129    1.2750    190.67  35.67
# 1130    1.2970    209.78  37.56
# 1131    1.2840    204.33  37.40
# 1132    1.3240    211.01  38.11
# 1133    1.3530    207.64  37.41
#
# [1134 rows x 9 columns]

# %%
pow.rename({'bitcoinSV_x':'bitcoinSV', 'eth_y':'eth', 'ltc_y':'ltc', 'minota_y':'minota', 'monero_y':'monero'}, axis=1, inplace=True)
pow
# Out:
#         datetime  bitcoin  bitcoinSV  bitcoin_cash      eth     ltc  minota  \
# 0     2018-11-19   225.29      70.00       4809.62   148.22   36.30  0.3552
# 1     2018-11-20   218.34      51.61       4441.81   130.74   32.84  0.3046
# 2     2018-11-21   241.61      52.41       4593.04   136.50   34.63  0.3323
# 3     2018-11-22   178.51      42.72       4320.68   125.08   31.74  0.3040
# 4     2018-11-23   140.64      54.73       4343.42   123.37   32.20  0.3207
# ...          ...      ...        ...           ...      ...     ...     ...
# 1129  2021-12-22   438.02     123.77      48614.97  3981.26  155.44  1.2750
# 1130  2021-12-23   455.69     129.46      50830.20  4112.35  163.67  1.2970
# 1131  2021-12-24   451.98     129.34      50840.36  4047.87  161.25  1.2840
# 1132  2021-12-25   455.35     128.25      50431.63  4097.06  157.77  1.3240
# 1133  2021-12-26   449.90     126.62      49861.38  4045.31  155.16  1.3530
#
#       monero    etc
# 0      72.10   6.21
# 1      66.05   5.58
# 2      68.62   5.78
# 3      65.29   5.24
# 4      66.63   5.22
# ...      ...    ...
# 1129  190.67  35.67
# 1130  209.78  37.56
# 1131  204.33  37.40
# 1132  211.01  38.11
# 1133  207.64  37.41
#
# [1134 rows x 9 columns]

# %%
pow = pow.dropna()
pow
# Out:
#         datetime  bitcoin  bitcoinSV  bitcoin_cash      eth     ltc  minota  \
# 0     2018-11-19   225.29      70.00       4809.62   148.22   36.30  0.3552
# 1     2018-11-20   218.34      51.61       4441.81   130.74   32.84  0.3046
# 2     2018-11-21   241.61      52.41       4593.04   136.50   34.63  0.3323
# 3     2018-11-22   178.51      42.72       4320.68   125.08   31.74  0.3040
# 4     2018-11-23   140.64      54.73       4343.42   123.37   32.20  0.3207
# ...          ...      ...        ...           ...      ...     ...     ...
# 1129  2021-12-22   438.02     123.77      48614.97  3981.26  155.44  1.2750
# 1130  2021-12-23   455.69     129.46      50830.20  4112.35  163.67  1.2970
# 1131  2021-12-24   451.98     129.34      50840.36  4047.87  161.25  1.2840
# 1132  2021-12-25   455.35     128.25      50431.63  4097.06  157.77  1.3240
# 1133  2021-12-26   449.90     126.62      49861.38  4045.31  155.16  1.3530
#
#       monero    etc
# 0      72.10   6.21
# 1      66.05   5.58
# 2      68.62   5.78
# 3      65.29   5.24
# 4      66.63   5.22
# ...      ...    ...
# 1129  190.67  35.67
# 1130  209.78  37.56
# 1131  204.33  37.40
# 1132  211.01  38.11
# 1133  207.64  37.41
#
# [1134 rows x 9 columns]

# %%
#Descriptive Analysis

# %%
pow.describe()
# Out:
#            bitcoin    bitcoinSV  bitcoin_cash          eth          ltc  \
# count  1134.000000  1134.000000   1134.000000  1134.000000  1134.000000
# mean    370.058907   159.623571  21164.771755  1039.645820   100.832892
# std     205.634973    64.341464  19057.778011  1315.292951    67.592275
# min      61.710000    42.720000   3232.510000    84.120000    23.120000
# 25%     230.610000   118.872500   7881.040000   172.692500    47.075000
# 50%     302.530000   162.720000  10339.020000   264.560000    72.750000
# 75%     484.672500   190.400000  36834.937500  1814.927500   148.492500
# max    1550.420000   439.930000  67549.140000  4810.970000   388.280000
#
#             minota       monero          etc
# count  1134.000000  1134.000000  1134.000000
# mean      0.570870   129.491464    17.458147
# std       0.505296    91.486751    21.591820
# min       0.110100    32.750000     3.473000
# 25%       0.255675    61.382500     5.237500
# 50%       0.304950    87.115000     6.566000
# 75%       0.840975   204.250000    12.732500
# max       2.521000   484.770000   133.590000

# %%
pow.to_csv(r'C:\Users\ASUS\Desktop\PoW111.csv', index = None)

# %%
##ADF test of BTC

# %%
Bitcoin_daydata = Pow.loc[:, 'bitcoin'].values

# %%
from statsmodels.tsa.stattools import adfuller
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
result = adfuller(Bitcoin_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, bitcoin in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {bitcoin}')
# Out:
# ADF Statistic: -0.5712951543064007
# n_lags: 0.8773371318070411
# p-value: 0.8773371318070411
# Critial Values:
#    1%, -3.437628610719785
# Critial Values:
#    5%, -2.8647531504389767
# Critial Values:
#    10%, -2.5684808963896324

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(Bitcoin_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Bitcoin')
# Out:
# Text(0.5, 1.0, 'Bitcoin')

# %%
BitCash_daydata = Pow.loc[:, 'bitcoin_cash'].values

# %%
result = adfuller(BitCash_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, bitcoin_cash in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {bitcoin_cash}')
# Out:
# ADF Statistic: -1.674772377864951
# n_lags: 0.4441551241347543
# p-value: 0.4441551241347543
# Critial Values:
#    1%, -3.437620518167552
# Critial Values:
#    5%, -2.8647495822909477
# Critial Values:
#    10%, -2.568478995776815

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(BitCash_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Bitcoin_Cash')
# Out:
# Text(0.5, 1.0, 'Bitcoin_Cash')

# %%
BitcoinSV_daydata = Pow.loc[:, 'bitcoinSV'].values

# %%
result = adfuller(BitCash_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, bitcoin_cash in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {bitcoin_cash}')
# Out:
# ADF Statistic: -1.674772377864951
# n_lags: 0.4441551241347543
# p-value: 0.4441551241347543
# Critial Values:
#    1%, -3.437620518167552
# Critial Values:
#    5%, -2.8647495822909477
# Critial Values:
#    10%, -2.568478995776815

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(BitcoinSV_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('BitcoinSV_daydata')
# Out:
# Text(0.5, 1.0, 'BitcoinSV_daydata')

# %%
daydata_ETH = Pow.loc[:, 'eth'].values

# %%
result = adfuller(daydata_ETH, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, eth in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {eth}')
# Out:
# ADF Statistic: 2.9222003872093567
# n_lags: 1.0
# p-value: 1.0
# Critial Values:
#    1%, -3.437628610719785
# Critial Values:
#    5%, -2.8647531504389767
# Critial Values:
#    10%, -2.5684808963896324

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(daydata_ETH);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('ETH_daydata')
# Out:
# Text(0.5, 1.0, 'ETH_daydata')

# %%
LTC_daydata = Pow.loc[:, 'ltc'].values

# %%
result = adfuller(LTC_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, ltc in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {ltc}')
# Out:
# ADF Statistic: -0.931191801582752
# n_lags: 0.7775270701486543
# p-value: 0.7775270701486543
# Critial Values:
#    1%, -3.4375723382479735
# Critial Values:
#    5%, -2.8647283387229963
# Critial Values:
#    10%, -2.568467680189796

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(LTC_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('LTC_daydata')
# Out:
# Text(0.5, 1.0, 'LTC_daydata')

# %%
Miota_daydata = Pow.loc[:, 'minota'].values

# %%
result = adfuller(Miota_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, minota in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {minota}')
# Out:
# ADF Statistic: -2.161589692675856
# n_lags: 0.22048023940361317
# p-value: 0.22048023940361317
# Critial Values:
#    1%, -3.437628610719785
# Critial Values:
#    5%, -2.8647531504389767
# Critial Values:
#    10%, -2.5684808963896324

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(Miota_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Miota_Daydata')
# Out:
# Text(0.5, 1.0, 'Miota_Daydata')

# %%
Monero_daydata = Pow.loc[:, 'monero'].values

# %%
result = adfuller(Monero_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, monero in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {monero}')
# Out:
# ADF Statistic: -1.3868553178015839
# n_lags: 0.5885613697257803
# p-value: 0.5885613697257803
# Critial Values:
#    1%, -3.437628610719785
# Critial Values:
#    5%, -2.8647531504389767
# Critial Values:
#    10%, -2.5684808963896324

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(Monero_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Monero_daydata')
# Out:
# Text(0.5, 1.0, 'Monero_daydata')

# %%
ETC_daydata =  Pow.loc[:, 'etc'].values

# %%
result = adfuller(ETC_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, etc in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {etc}')
# Out:
# ADF Statistic: -1.0509352323876222
# n_lags: 0.7342368033347328
# p-value: 0.7342368033347328
# Critial Values:
#    1%, -3.437628610719785
# Critial Values:
#    5%, -2.8647531504389767
# Critial Values:
#    10%, -2.5684808963896324

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(ETC_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('ETC_daydata')
# Out:
# Text(0.5, 1.0, 'ETC_daydata')

# %%
PoW = pd.merge(Pow, proof_type1, how='outer',
                  left_on='datetime', right_on='datetime' )

# %%
PoW.to_csv(r'C:\Users\ASUS\Desktop\Data set\PoW.csv', index = None)

# %%
##Engle-Granger Test

# %%
PoW_proof = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\PoW1.csv')

# %%
PoW_proof
# Out:
#        datetime  bitcoin  bitcoin_cash  bitcoinSV     eth    ltc  minota  \
# 0    11/19/2018  4809.62        225.29      70.00  148.22  36.30  0.3552
# 1    11/20/2018  4441.81        218.34      51.61  130.74  32.84  0.3046
# 2    11/21/2018  4593.04        241.61      52.41  136.50  34.63  0.3323
# 3    11/22/2018  4320.68        178.51      42.72  125.08  31.74  0.3040
# 4    11/23/2018  4343.42        140.64      54.73  123.37  32.20  0.3207
# ..          ...      ...           ...        ...     ...    ...     ...
# 561    6/2/2020  9523.75        251.05     196.00  237.81  46.01  0.2341
# 562    6/3/2020  9666.06        253.15     194.77  244.65  47.17  0.2502
# 563    6/4/2020  9794.55        256.32     195.11  243.35  47.47  0.2490
# 564    6/5/2020  9622.02        256.04     194.56  240.08  46.81  0.2400
# 565    6/6/2020  9671.46        253.30     194.40  242.08  46.80  0.2437
#
#      monero    etc
# 0     72.10  6.210
# 1     66.05  5.580
# 2     68.62  5.780
# 3     65.29  5.240
# 4     66.63  5.220
# ..      ...    ...
# 561   66.64  6.982
# 562   67.21  6.943
# 563   68.11  6.916
# 564   67.40  6.842
# 565   67.72  6.868
#
# [566 rows x 9 columns]

# %%
## Cointegration between Bitcoin & BitcoinCash in 11/19/2018 to 6/6/2020

# %%
df = pd.DataFrame(PoW_proof, columns= ['bitcoin','bitcoin_cash'])
X = df["bitcoin"]
y = df["bitcoin_cash"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -2.347611
# p-value                                                               0.350051
# Critical Values 1%,5%,10%    [-3.9159289200407237, -3.3469657099224683, -3....
# dtype: object

# %%
## 11/19/2018 to 6/6/2020

# %%
## Cointegration between BitcoinSV & Bitcoin in 11/19/2018 to 6/6/2020

# %%
df = pd.DataFrame(PoW_proof, columns= ['bitcoin','bitcoinSV'])
X = df["bitcoin"]
y = df["bitcoinSV"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -2.612372
# p-value                                                               0.231875
# Critical Values 1%,5%,10%    [-3.9159289200407237, -3.3469657099224683, -3....
# dtype: object

# %%
## Cointegration between BitcoinSV & Etherium in 11/19/2018 to 6/6/2020

# %%
df = pd.DataFrame(PoW_proof, columns= ['bitcoin','eth'])
X = df["bitcoin"]
y = df["eth"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -2.546139
# p-value                                                               0.259108
# Critical Values 1%,5%,10%    [-3.9159289200407237, -3.3469657099224683, -3....
# dtype: object

# %%
## Cointegration between Bitcoin & ltc in 11/19/2018 to 6/6/2020

# %%
df = pd.DataFrame(PoW_proof, columns= ['bitcoin','ltc'])
X = df["bitcoin"]
y = df["ltc"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -1.375224
# p-value                                                                0.80588
# Critical Values 1%,5%,10%    [-3.9159289200407237, -3.3469657099224683, -3....
# dtype: object

# %%
##Cointegration between BitcoinSV & minota in 11/19/2018 to 6/6/2020

# %%
df = pd.DataFrame(PoW_proof, columns= ['bitcoin','minota'])
X = df["bitcoin"]
y = df["minota"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -2.180248
# p-value                                                               0.434571
# Critical Values 1%,5%,10%    [-3.9159289200407237, -3.3469657099224683, -3....
# dtype: object

# %%
##Cointegration between BitcoinSV & monero in 11/19/2018 to 6/6/2020

# %%
df = pd.DataFrame(PoW_proof, columns= ['bitcoin','monero'])
X = df["bitcoin"]
y = df["monero"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -2.475397
# p-value                                                               0.290026
# Critical Values 1%,5%,10%    [-3.9159289200407237, -3.3469657099224683, -3....
# dtype: object

# %%
##Cointegration between BitcoinSV & etc in 11/19/2018 to 6/6/2020

# %%
df = pd.DataFrame(PoW_proof, columns= ['bitcoin','etc'])
X = df["bitcoin"]
y = df["etc"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -2.429287
# p-value                                                               0.311112
# Critical Values 1%,5%,10%    [-3.9159289200407237, -3.3469657099224683, -3....
# dtype: object

# %%
## Cointegration test from 6/7/2020 to 12/26/2021

# %%
PoW_proof = pd.read_csv(r'C:\Users\ASUS\Desktop\daydata\PoW2.csv')

# %%
PoW_proof
# Out:
#       datetime   bitcoin  bitcoin_cash  bitcoinSV      eth     ltc  minota  \
# 0     6/7/2020   9750.70        253.62     192.38   244.75   46.64  0.2399
# 1     6/8/2020   9782.58        255.42     191.84   246.47   46.45  0.2408
# 2     6/9/2020   9779.70        254.27     189.73   244.00   45.94  0.2470
# 3    6/10/2020   9891.84        257.29     194.08   248.01   46.69  0.2509
# 4    6/11/2020   9268.13        234.55     180.08   230.21   43.20  0.2230
# ..         ...       ...           ...        ...      ...     ...     ...
# 352  5/25/2021  38387.36        719.16     175.20  2707.49  183.82  1.0620
# 353  5/26/2021  39295.08        764.50     181.94  2888.94  199.17  1.2700
# 354  5/27/2021  38538.84        749.64     183.56  2742.48  193.97  1.1610
# 355  5/28/2021  35680.92        689.09     168.09  2412.36  177.40  1.0340
# 356  5/29/2021  34611.58        651.87     164.30  2278.58  163.95  0.9681
#
#      monero     etc
# 0     66.46   6.838
# 1     68.26   6.904
# 2     68.13   6.786
# 3     69.68   6.818
# 4     63.63   6.253
# ..      ...     ...
# 352  246.98  77.810
# 353  268.90  78.390
# 354  251.58  73.490
# 355  262.50  67.870
# 356  242.77  63.930
#
# [357 rows x 9 columns]

# %%
## Cointegration between Bitcoin & BitcoinCash in

# %%
df = pd.DataFrame(PoW_proof, columns= ['bitcoin','bitcoin_cash'])
X = df["bitcoin"]
y = df["bitcoin_cash"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -2.004877
# p-value                                                               0.526042
# Critical Values 1%,5%,10%    [-3.9274683060850903, -3.3533470385683626, -3....
# dtype: object

# %%
## Cointegration between BitcoinSV & Bitcoin in 6/7/2020 to 12/26/2021

# %%
df = pd.DataFrame(PoW_proof, columns= ['bitcoin','bitcoinSV'])
X = df["bitcoin"]
y = df["bitcoinSV"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -3.322924
# p-value                                                               0.051662
# Critical Values 1%,5%,10%    [-3.9274683060850903, -3.3533470385683626, -3....
# dtype: object

# %%
## Cointegration between BitcoinSV & Etherium in 6/7/2020 to 12/26/2021

# %%
df = pd.DataFrame(PoW_proof, columns= ['bitcoin','eth'])
X = df["bitcoin"]
y = df["eth"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -2.887444
# p-value                                                                0.13944
# Critical Values 1%,5%,10%    [-3.9274683060850903, -3.3533470385683626, -3....
# dtype: object

# %%
## Cointegration between Bitcoin & ltc in 6/7/2020 to 12/26/2021

# %%
df = pd.DataFrame(PoW_proof, columns= ['bitcoin','ltc'])
X = df["bitcoin"]
y = df["ltc"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -1.432421
# p-value                                                               0.786184
# Critical Values 1%,5%,10%    [-3.9274683060850903, -3.3533470385683626, -3....
# dtype: object

# %%
##Cointegration between BitcoinSV & minota in 6/7/2020 to 12/26/2021

# %%
df = pd.DataFrame(PoW_proof, columns= ['bitcoin','minota'])
X = df["bitcoin"]
y = df["minota"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -1.591857
# p-value                                                               0.724315
# Critical Values 1%,5%,10%    [-3.9274683060850903, -3.3533470385683626, -3....
# dtype: object

# %%
##Cointegration between BitcoinSV & monero in 6/7/2020 to 12/26/2021

# %%
df = pd.DataFrame(PoW_proof, columns= ['bitcoin','monero'])
X = df["bitcoin"]
y = df["monero"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -2.606368
# p-value                                                               0.234272
# Critical Values 1%,5%,10%    [-3.9274683060850903, -3.3533470385683626, -3....
# dtype: object

# %%
##Cointegration between BitcoinSV & etc in 6/7/2020 to 12/26/2021

# %%
df = pd.DataFrame(PoW_proof, columns= ['bitcoin','etc'])
X = df["bitcoin"]
y = df["etc"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                          0.2231
# p-value                                                               0.989933
# Critical Values 1%,5%,10%    [-3.9274683060850903, -3.3533470385683626, -3....
# dtype: object

# %%
PoW_proof1 = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_AR')

# %%
PoW_proof2 = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\PoW.csv')

# %%
PoW_final = pd.merge(PoW_proof2, PoW_proof1, how='outer',
                  left_on='datetime', right_on='datetime' )

# %%
PoW_final
# Out:
#         datetime  close_A  close_B  close_C  close_D  close_E  close_F  \
# 0     11/19/2018  4809.62   225.29    70.00   148.22    36.30   0.3552
# 1     11/20/2018  4441.81   218.34    51.61   130.74    32.84   0.3046
# 2     11/21/2018  4593.04   241.61    52.41   136.50    34.63   0.3323
# 3     11/22/2018  4320.68   178.51    42.72   125.08    31.74   0.3040
# 4     11/23/2018  4343.42   140.64    54.73   123.37    32.20   0.3207
# ...          ...      ...      ...      ...      ...      ...      ...
# 1688  2021-12-22      NaN      NaN      NaN      NaN      NaN      NaN
# 1689  2021-12-23      NaN      NaN      NaN      NaN      NaN      NaN
# 1690  2021-12-24      NaN      NaN      NaN      NaN      NaN      NaN
# 1691  2021-12-25      NaN      NaN      NaN      NaN      NaN      NaN
# 1692  2021-12-26      NaN      NaN      NaN      NaN      NaN      NaN
#
#       close_G  close_H  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0       72.10     6.21         NaN          NaN          NaN          NaN
# 1       66.05     5.58         NaN          NaN          NaN          NaN
# 2       68.62     5.78         NaN          NaN          NaN          NaN
# 3       65.29     5.24         NaN          NaN          NaN          NaN
# 4       66.63     5.22         NaN          NaN          NaN          NaN
# ...       ...      ...         ...          ...          ...          ...
# 1688      NaN      NaN         NaN          NaN          NaN          NaN
# 1689      NaN      NaN         NaN          NaN          NaN          NaN
# 1690      NaN      NaN         NaN          NaN          NaN          NaN
# 1691      NaN      NaN         NaN          NaN          NaN          NaN
# 1692      NaN      NaN         NaN          NaN          NaN          NaN
#
#         low   high   open  close  volumefrom     volumeto
# 0       NaN    NaN    NaN    NaN         NaN          NaN
# 1       NaN    NaN    NaN    NaN         NaN          NaN
# 2       NaN    NaN    NaN    NaN         NaN          NaN
# 3       NaN    NaN    NaN    NaN         NaN          NaN
# 4       NaN    NaN    NaN    NaN         NaN          NaN
# ...     ...    ...    ...    ...         ...          ...
# 1688  52.90  56.53  54.35  53.20   684896.15  36436475.18
# 1689  51.72  57.74  53.20  57.33   677012.02  38813099.11
# 1690  55.31  64.59  57.33  61.88  1270810.49  78637753.12
# 1691  60.13  68.48  61.88  60.48  1059717.34  64091704.72
# 1692  57.80  62.91  60.57  61.60    17323.52   1067145.25
#
# [1693 rows x 19 columns]

# %%
## AFD & Engle-Granger Test of Arewave

# %%
PoW_final.to_csv(r'C:\Users\ASUS\Desktop\Data set\PoW_final.csv', index = None)

# %%
ar = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\ar.csv')

# %%
ar
# Out:
#        datetime  arwave   bitcoin
# 0     6/16/2020   1.329   9526.70
# 1     6/17/2020   1.343   9459.13
# 2     6/18/2020   1.282   9380.67
# 3     6/19/2020   1.569   9301.83
# 4     6/20/2020   1.424   9359.18
# ..          ...     ...       ...
# 554  12/22/2021  53.200  48614.97
# 555  12/23/2021  57.330  50830.20
# 556  12/24/2021  61.880  50840.36
# 557  12/25/2021  60.480  50431.63
# 558  12/26/2021  61.600  49861.38
#
# [559 rows x 3 columns]

# %%
from statsmodels.tsa.stattools import adfuller
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
ar1 = ar.loc[:, 'arwave'].values

# %%
result = adfuller(ar1, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, arwave in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {arwave}')
# Out:
# ADF Statistic: -0.6112893674263811
# n_lags: 0.8684106332313104
# p-value: 0.8684106332313104
# Critial Values:
#    1%, -3.442517884424376
# Critial Values:
#    5%, -2.8669071815780116
# Critial Values:
#    10%, -2.5696285219478736

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(ar1);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Arwave Daily_data')
# Out:
# Text(0.5, 1.0, 'Arwave Daily_data')

# %%
df = pd.DataFrame(ar, columns= ['bitcoin','arwave'])
X = df["bitcoin"]
y = df["arwave"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -1.411061
# p-value                                                               0.793697
# Critical Values 1%,5%,10%    [-3.916174738762349, -3.3471019132590794, -3.0...
# dtype: object

# %%
## Proof Type - DPoS ------------------------ Daily Data

# %%
EOS = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_EOS')

# %%
Terra = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_LUNA')

# %%
BitTorrent = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_BTT(bitTorent)')

# %%
Tron = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_TRX(Tron)')

# %%
Tezos = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_XTZ(Tezos)')

# %%
Dpos = pd.merge(EOS, Terra, how='outer',
                  left_on='datetime', right_on='datetime' )

# %%
Dpos1 = pd.merge(Dpos, BitTorrent, how='outer',
                  left_on='datetime', right_on='datetime' )

# %%
Dpos2 = pd.merge(Dpos1, Tron, how='outer',
                  left_on='datetime', right_on='datetime' )

# %%
Dpos3 = pd.merge(Dpos2, Tezos, how='outer',
                  left_on='datetime', right_on='datetime' )

# %%
Dpos3
# Out:
#         datetime   low_x  high_x  open_x  close_x  volumefrom_x   volumeto_x  \
# 0     2017-06-29  0.6151   1.406  0.8812   0.8494      90303.10     76704.36
# 1     2017-06-30  0.7516   1.094  0.9568   0.9327      63051.61     58808.83
# 2     2017-07-01  0.5361   1.580  0.9793   1.2730     269593.63    343235.29
# 3     2017-07-02  0.9455   3.880  1.0500   3.0000    3376175.73   7026243.78
# 4     2017-07-03  2.5000   6.900  3.0000   4.2000    5163248.87  21951537.56
# ...          ...     ...     ...     ...      ...           ...          ...
# 1762  2017-06-24     NaN     NaN     NaN      NaN           NaN          NaN
# 1763  2017-06-25     NaN     NaN     NaN      NaN           NaN          NaN
# 1764  2017-06-26     NaN     NaN     NaN      NaN           NaN          NaN
# 1765  2017-06-27     NaN     NaN     NaN      NaN           NaN          NaN
# 1766  2017-06-28     NaN     NaN     NaN      NaN           NaN          NaN
#
#         low_y   high_y   open_y  ...  open_y  close_y  volumefrom_y  \
# 0     0.02280  0.03543  0.02604  ...     NaN      NaN           NaN
# 1     0.02148  0.03073  0.03057  ...     NaN      NaN           NaN
# 2     0.02124  0.02679  0.02488  ...     NaN      NaN           NaN
# 3     0.02240  0.02410  0.02303  ...     NaN      NaN           NaN
# 4     0.02256  0.02837  0.02283  ...     NaN      NaN           NaN
# ...       ...      ...      ...  ...     ...      ...           ...
# 1762  0.01997  0.02590  0.02710  ...     NaN      NaN           NaN
# 1763  0.01960  0.02397  0.01997  ...     NaN      NaN           NaN
# 1764  0.01891  0.02307  0.02397  ...     NaN      NaN           NaN
# 1765  0.01992  0.02558  0.02304  ...     NaN      NaN           NaN
# 1766  0.02070  0.02964  0.02558  ...     NaN      NaN           NaN
#
#       volumeto_y     low   high    open   close  volumefrom  volumeto
# 0            NaN  2.1750  3.198  2.3200  3.1980     3352.23  10720.31
# 1            NaN  2.2380  3.225  3.1980  2.2420     8521.82  19109.94
# 2            NaN  0.6062  3.031  2.2420  0.6062    14333.67   8688.39
# 3            NaN  0.6341  1.776  0.6062  1.6460    13387.06  22037.28
# 4            NaN  0.5196  1.801  1.6460  0.8232    26854.14  22106.07
# ...          ...     ...    ...     ...     ...         ...       ...
# 1762         NaN  1.4250  5.154  3.9540  2.2020    12904.99  28410.88
# 1763         NaN  2.0000  3.025  2.2020  3.0220    12905.60  39000.54
# 1764         NaN  1.9080  3.657  3.0220  1.9400     8351.27  16199.11
# 1765         NaN  2.0130  3.876  1.9400  3.5910    11791.14  42346.85
# 1766         NaN  2.2890  3.660  3.5910  2.3200     2829.30   6563.88
#
# [1767 rows x 31 columns]

# %%
Dpos3.to_csv(r'C:\Users\ASUS\Desktop\Data set\Dpos3.csv', index = None)

# %%
##   -----------------------------------------  ADF TEST  --------------------------------------------------------

# %%
DPoS = pd.read_csv(r'C:\Users\ASUS\Desktop\daydata\Dpos3.csv')

# %%
DPoS
# Out:
#         datetime    eos       terra  bittorrent     tron   tezos
# 0       2/3/2019  2.400    0.001276    0.000621  0.02566  0.3701
# 1       2/4/2019  2.420    0.002573    0.000858  0.02718  0.3643
# 2       2/5/2019  2.420    0.002896    0.000996  0.02659  0.3703
# 3       2/7/2019  2.370    0.002059    0.000916  0.02618  0.3620
# 4       2/8/2019  2.770    0.002159    0.000874  0.02720  0.3834
# ...          ...    ...         ...         ...      ...     ...
# 1043  12/22/2021  3.356   85.420000    0.002708  0.07912  4.5250
# 1044  12/23/2021  3.504   94.240000    0.002868  0.08269  4.7720
# 1045  12/24/2021  3.378   95.880000    0.002789  0.08084  4.4910
# 1046  12/25/2021  3.410   98.340000    0.002831  0.08159  4.5830
# 1047  12/26/2021  3.366  100.030000    0.002783  0.08067  4.8740
#
# [1048 rows x 6 columns]

# %%
DPoS.describe()
# Out:
#                eos        terra   bittorrent         tron        tezos
# count  1048.000000  1048.000000  1048.000000  1048.000000  1048.000000
# mean      3.919314     8.026974     0.001517     0.041689     2.740652
# std       1.476087    16.179778     0.001836     0.033283     1.712427
# min       1.794000     0.001272     0.000189     0.008505     0.362000
# 25%       2.760500     0.197375     0.000336     0.017577     1.314750
# 50%       3.630000     0.345000     0.000585     0.026540     2.408500
# 75%       4.624500     6.578750     0.002471     0.060003     3.496250
# max      14.530000   100.030000     0.010350     0.164400     8.698000

# %%
EOS = DPoS.loc[:, 'eos'].values

# %%
result = adfuller(EOS, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, eos in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {eos}')
# Out:
# ADF Statistic: -3.187534065762191
# n_lags: 0.02071769103273817
# p-value: 0.02071769103273817
# Critial Values:
#    1%, -3.436659460539809
# Critial Values:
#    5%, -2.864325767240336
# Critial Values:
#    10%, -2.5682532565554537

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(EOS);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('EOS Daily_data')
# Out:
# Text(0.5, 1.0, 'EOS Daily_data')

# %%
Terra = DPoS.loc[:, 'terra'].values

# %%
result = adfuller(Terra, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, terra in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {terra}')
# Out:
# ADF Statistic: 4.586235532879431
# n_lags: 1.0
# p-value: 1.0
# Critial Values:
#    1%, -3.43674585579594
# Critial Values:
#    5%, -2.8643638720413227
# Critial Values:
#    10%, -2.5682735516954196

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(Terra);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Terra')
# Out:
# Text(0.5, 1.0, 'Terra')

# %%
BitTorrent = DPoS.loc[:, 'bittorrent'].values

# %%
result = adfuller(BitTorrent, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, bittorrent in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {bittorrent}')
# Out:
# ADF Statistic: -2.2067594976662592
# n_lags: 0.20380130288380627
# p-value: 0.20380130288380627
# Critial Values:
#    1%, -3.436714730058834
# Critial Values:
#    5%, -2.8643501440982058
# Critial Values:
#    10%, -2.5682662399849185

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(BitTorrent);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('BitTorrent')
# Out:
# Text(0.5, 1.0, 'BitTorrent')

# %%
Tron = DPoS.loc[:, 'tron'].values

# %%
result = adfuller(Tron, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, tron in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {tron}')
# Out:
# ADF Statistic: -1.2630853264106316
# n_lags: 0.6458871468968787
# p-value: 0.6458871468968787
# Critial Values:
#    1%, -3.4367333690404767
# Critial Values:
#    5%, -2.8643583648001925
# Critial Values:
#    10%, -2.568270618452702

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(Tron);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Terra')
# Out:
# Text(0.5, 1.0, 'Terra')

# %%
Tezos = DPoS.loc[:, 'tezos'].values

# %%
result = adfuller(Tezos, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, tezos in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {tezos}')
# Out:
# ADF Statistic: -1.8071096786796572
# n_lags: 0.3769376922444641
# p-value: 0.3769376922444641
# Critial Values:
#    1%, -3.4367396063176874
# Critial Values:
#    5%, -2.8643611157329905
# Critial Values:
#    10%, -2.5682720836420705

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(Tezos);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Tezos')
# Out:
# Text(0.5, 1.0, 'Tezos')

# %%
##       -------------------------------------------- Engle-Granger Test -----------------------------------------------

# %%
dpos1 = pd.read_csv(r'C:\Users\ASUS\Desktop\daydata\dpos2.csv')

# %%
dpos1
# Out:
#       datetime    eos     terra  bittorrent     tron   tezos
# 0     2/3/2019  2.400  0.001276    0.000621  0.02566  0.3701
# 1     2/4/2019  2.420  0.002573    0.000858  0.02718  0.3643
# 2     2/5/2019  2.420  0.002896    0.000996  0.02659  0.3703
# 3     2/7/2019  2.370  0.002059    0.000916  0.02618  0.3620
# 4     2/8/2019  2.770  0.002159    0.000874  0.02720  0.3834
# ..         ...    ...       ...         ...      ...     ...
# 519  7/16/2020  2.501  0.234400    0.000378  0.01717  3.0970
# 520  7/17/2020  2.497  0.261000    0.000375  0.01722  3.1710
# 521  7/18/2020  2.504  0.272800    0.000391  0.01743  3.0110
# 522  7/19/2020  2.585  0.341800    0.000381  0.01757  2.9870
# 523  7/20/2020  2.566  0.342200    0.000387  0.01721  2.7700
#
# [524 rows x 6 columns]

# %%
## Engle-Granger test of terra and bittorrent from 2/3/2019 to 7/20/2020

# %%
df = pd.DataFrame(dpos1, columns= ['terra','bittorrent'])
X = df["terra"]
y = df["bittorrent"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -1.705584
# p-value                                                               0.674349
# Critical Values 1%,5%,10%    [-3.9175031073853233, -3.3478377359256237, -3....
# dtype: object

# %%
## Engle-Granger test of terra and tron from 2/3/2019 to 7/20/2020

# %%
df = pd.DataFrame(dpos1, columns= ['terra','tron'])
X = df["terra"]
y = df["tron"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                        -2.70043
# p-value                                                               0.199424
# Critical Values 1%,5%,10%    [-3.9175031073853233, -3.3478377359256237, -3....
# dtype: object

# %%
## Engle-Granger test of terra and tezos from 2/3/2019 to 7/20/2020

# %%
df = pd.DataFrame(dpos1, columns= ['terra','tezos'])
X = df["terra"]
y = df["tezos"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -1.642791
# p-value                                                               0.702495
# Critical Values 1%,5%,10%    [-3.9175031073853233, -3.3478377359256237, -3....
# dtype: object

# %%
##               ---------------------------- Eangle-Granger Test --------------------------------

# %%
dpos1 = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\dpos1.csv')

# %%
dpos1
# Out:
#        datetime    eos     terra  bittorrent     tron  tezos
# 0     7/20/2020  2.566    0.3422    0.000387  0.01721  2.770
# 1     7/21/2020  2.625    0.3269    0.000394  0.01742  3.025
# 2     7/22/2020  2.667    0.3833    0.000392  0.01794  3.110
# 3     7/23/2020  2.659    0.4007    0.000389  0.01789  3.189
# 4     7/24/2020  2.600    0.3803    0.000389  0.01796  3.035
# ..          ...    ...       ...         ...      ...    ...
# 520  12/22/2021  3.356   85.4200    0.002708  0.07912  4.525
# 521  12/23/2021  3.504   94.2400    0.002868  0.08269  4.772
# 522  12/24/2021  3.378   95.8800    0.002789  0.08084  4.491
# 523  12/25/2021  3.410   98.3400    0.002831  0.08159  4.583
# 524  12/26/2021  3.366  100.0300    0.002783  0.08067  4.874
#
# [525 rows x 6 columns]

# %%
## Engle-Granger test of terra and bittorrent from 7/20/2020 to 12/26/2021

# %%
df = pd.DataFrame(dpos1, columns= ['terra','bittorrent'])
X = df["terra"]
y = df["bittorrent"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -1.613647
# p-value                                                               0.715096
# Critical Values 1%,5%,10%    [-3.917462677145854, -3.3478153454052793, -3.0...
# dtype: object

# %%
df = pd.DataFrame(dpos1, columns= ['terra','tron'])
X = df["terra"]
y = df["tron"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -0.978328
# p-value                                                               0.906881
# Critical Values 1%,5%,10%    [-3.917462677145854, -3.3478153454052793, -3.0...
# dtype: object

# %%
df = pd.DataFrame(dpos1, columns= ['terra','tezos'])
X = df["terra"]
y = df["tezos"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -1.916058
# p-value                                                                0.57184
# Critical Values 1%,5%,10%    [-3.917462677145854, -3.3478153454052793, -3.0...
# dtype: object

# %%
##                      -----------------Proof Type: POS----------------------

# %%
import pandas as pd

# %%
cardano = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_ADA(cardano)')

# %%
algorand = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_ALGO')

# %%
algorand
# Out:
#        datetime    low   high   open  close   volumefrom     volumeto
# 0    2019-06-21  3.091  3.386  3.006  3.166    107750.34    341116.66
# 1    2019-06-22  1.865  3.385  3.150  2.173    422124.64    917401.72
# 2    2019-06-23  1.715  2.176  2.173  1.912    352068.69    673207.71
# 3    2019-06-24  1.316  2.101  1.912  1.413    872894.44   1233618.08
# 4    2019-06-25  1.330  1.936  1.413  1.526   1038101.82   1584134.17
# ..          ...    ...    ...    ...    ...          ...          ...
# 915  2021-12-22  1.343  1.417  1.358  1.364  26251227.31  36222072.56
# 916  2021-12-23  1.345  1.489  1.364  1.470  26150560.79  36997591.56
# 917  2021-12-24  1.447  1.650  1.470  1.575  44863094.83  70098722.93
# 918  2021-12-25  1.532  1.600  1.575  1.576  16764421.09  26270626.78
# 919  2021-12-26  1.546  1.640  1.576  1.623  16089743.22  25640966.82
#
# [920 rows x 7 columns]

# %%
anchor_protocol = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_ANC')

# %%
cosmos = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_ATOM')

# %%
avalanche = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_AVAX')

# %%
crypto_com = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_CRO(crypto.com)')

# %%
hedera_hashgraph = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_HBAR(hashbar)')

# %%
internet_computer = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_ICP(internet computer)')

# %%
near = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_NEAR')

# %%
PayProtocol = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_PCI(Paycoin Price )')

# %%
Oasis_labs = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_ROSE')

# %%
terraUSD = pd.read_csv(r'C:\Users\ASUS\Desktop\Data set\daydata_UST(terraUSD)')

# %%
POS10 = pd.merge(POS9, terraUSD, how='outer',
                  left_on='datetime', right_on='datetime' )

# %%
POS10
# Out:
#         datetime    low_x   high_x   open_x  close_x  volumefrom_x  \
# 0     2017-10-01  0.01497  0.08806  0.03925  0.02519  1.714880e+09
# 1     2017-10-02  0.01972  0.03063  0.02519  0.02588  2.193437e+09
# 2     2017-10-03  0.02066  0.02683  0.02588  0.02084  7.182628e+08
# 3     2017-10-04  0.02033  0.02308  0.02084  0.02189  4.129679e+08
# 4     2017-10-05  0.02096  0.02269  0.02189  0.02152  2.516286e+08
# ...          ...      ...      ...      ...      ...           ...
# 1543  2021-12-22  1.27700  1.36700  1.28100  1.32800  3.182877e+07
# 1544  2021-12-23  1.30800  1.49000  1.32800  1.47400  4.890100e+07
# 1545  2021-12-24  1.38300  1.49000  1.47400  1.39200  2.831958e+07
# 1546  2021-12-25  1.38200  1.46000  1.39200  1.45400  2.028981e+07
# 1547  2021-12-26  1.40900  1.46700  1.45400  1.43800  1.343253e+07
#
#        volumeto_x  low_y  high_y  open_y  ...  open_x  close_x  volumefrom_x  \
# 0     43190415.57    NaN     NaN     NaN  ...     NaN      NaN           NaN
# 1     56765624.40    NaN     NaN     NaN  ...     NaN      NaN           NaN
# 2     14966793.97    NaN     NaN     NaN  ...     NaN      NaN           NaN
# 3      9041869.33    NaN     NaN     NaN  ...     NaN      NaN           NaN
# 4      5415241.93    NaN     NaN     NaN  ...     NaN      NaN           NaN
# ...           ...    ...     ...     ...  ...     ...      ...           ...
# 1543  42231132.32  1.343   1.417   1.358  ...  0.2616   0.2700  2.088718e+08
# 1544  68643605.39  1.345   1.489   1.364  ...  0.2700   0.3177  3.910638e+08
# 1545  40815999.85  1.447   1.650   1.470  ...  0.3177   0.3047  1.987281e+08
# 1546  29025706.45  1.532   1.600   1.575  ...  0.3047   0.3417  2.596136e+08
# 1547  19295154.93  1.546   1.640   1.576  ...  0.3445   0.3462  7.528184e+05
#
#         volumeto_x  low_y  high_y  open_y  close_y  volumefrom_y  volumeto_y
# 0              NaN    NaN     NaN     NaN      NaN           NaN         NaN
# 1              NaN    NaN     NaN     NaN      NaN           NaN         NaN
# 2              NaN    NaN     NaN     NaN      NaN           NaN         NaN
# 3              NaN    NaN     NaN     NaN      NaN           NaN         NaN
# 4              NaN    NaN     NaN     NaN      NaN           NaN         NaN
# ...            ...    ...     ...     ...      ...           ...         ...
# 1543  5.639538e+07  1.003   1.014   1.009    1.003    7178584.96  7210656.06
# 1544  1.242410e+08  1.000   1.004   1.003    1.001    7377491.80  7390783.10
# 1545  6.055247e+07  1.001   1.003   1.001    1.001    5157726.79  5168357.12
# 1546  8.870997e+07  1.001   1.002   1.001    1.001    1212532.17  1214659.78
# 1547  2.493583e+05  1.001   1.002   1.001    1.001    1064792.83  1066487.94
#
# [1548 rows x 73 columns]

# %%
POS10.to_csv(r'C:\Users\ASUS\Desktop\Data set\POS.csv', index = None)

# %%
##                          ----------------POS1----ADF TEST----------------

# %%
POS = pd.read_csv(r'C:\Users\ASUS\Desktop\daydata\POS.csv')
POS
# Out:
#         datetime  cardano  algorand  anchor_protocol  cosmos  avalanche  \
# 0      10/1/2017  0.02519       NaN              NaN     NaN        NaN
# 1      10/2/2017  0.02588       NaN              NaN     NaN        NaN
# 2      10/3/2017  0.02084       NaN              NaN     NaN        NaN
# 3      10/4/2017  0.02189       NaN              NaN     NaN        NaN
# 4      10/5/2017  0.02152       NaN              NaN     NaN        NaN
# ...          ...      ...       ...              ...     ...        ...
# 1543  12/22/2021  1.32800     1.364            3.717   27.28     116.67
# 1544  12/23/2021  1.47400     1.470            3.751   28.37     121.36
# 1545  12/24/2021  1.39200     1.575            3.986   26.87     114.89
# 1546  12/25/2021  1.45400     1.576            4.040   29.68     115.01
# 1547  12/26/2021  1.43800     1.623            4.007   31.35     112.11
#
#       crypto_com  hedera_hashgraph  internet_computer   near  PayProtocol  \
# 0            NaN               NaN                NaN    NaN          NaN
# 1            NaN               NaN                NaN    NaN          NaN
# 2            NaN               NaN                NaN    NaN          NaN
# 3            NaN               NaN                NaN    NaN          NaN
# 4            NaN               NaN                NaN    NaN          NaN
# ...          ...               ...                ...    ...          ...
# 1543      0.5367            0.3185              23.32  10.82        1.377
# 1544      0.5949            0.3290              26.96  13.73        1.421
# 1545      0.6278            0.3108              27.61  14.94        1.415
# 1546      0.6436            0.3150              27.28  15.20        1.401
# 1547      0.6154            0.3182              26.37  14.88        1.417
#
#       Oasis_labs  terraUSD
# 0            NaN       NaN
# 1            NaN       NaN
# 2            NaN       NaN
# 3            NaN       NaN
# 4            NaN       NaN
# ...          ...       ...
# 1543      0.2700     1.003
# 1544      0.3177     1.001
# 1545      0.3047     1.001
# 1546      0.3417     1.001
# 1547      0.3462     1.001
#
# [1548 rows x 13 columns]

# %%
POS.describe()
# Out:
#            cardano    algorand  anchor_protocol      cosmos   avalanche  \
# count  1548.000000  920.000000       234.000000  979.000000  461.000000
# mean      0.439059    0.709135         3.067051   10.273178   32.872393
# std       0.667589    0.557039         0.804352    9.977333   31.788081
# min       0.018490    0.126300         1.711000    1.607000    2.900000
# 25%       0.049085    0.260225         2.614500    3.640000    9.392000
# 50%       0.097895    0.411900         3.058500    5.118000   23.560000
# 75%       0.376600    1.057500         3.419000   14.450000   47.450000
# max       2.968000    3.166000         5.639000   44.240000  134.960000
#
#         crypto_com  hedera_hashgraph  internet_computer        near  \
# count  1017.000000        829.000000         231.000000  438.000000
# mean      0.121825          0.130991          62.577403    4.684931
# std       0.120677          0.130558          52.353135    3.246666
# min       0.026060          0.010090          21.760000    0.533600
# 25%       0.055000          0.033600          40.895000    2.076750
# 50%       0.078460          0.043960          46.940000    4.048500
# 75%       0.154200          0.237000          61.935000    6.863250
# max       0.889200          0.505100         426.980000   15.200000
#
#        PayProtocol  Oasis_labs    terraUSD
# count   573.000000  390.000000  471.000000
# mean      0.712907    0.137498    1.001885
# std       0.674426    0.081154    0.008488
# min       0.040670    0.036160    0.949900
# 25%       0.165900    0.066350    0.999450
# 50%       0.457200    0.119300    1.001000
# 75%       1.094000    0.191075    1.002500
# max       4.170000    0.415800    1.101000

# %%
Pos1 = POS.loc[:, ['datetime', 'cardano', 'algorand', 'cosmos', 'crypto_com', 'hedera_hashgraph',]]
Pos1
# Out:
#         datetime  cardano  algorand  cosmos  crypto_com  hedera_hashgraph
# 0      10/1/2017  0.02519       NaN     NaN         NaN               NaN
# 1      10/2/2017  0.02588       NaN     NaN         NaN               NaN
# 2      10/3/2017  0.02084       NaN     NaN         NaN               NaN
# 3      10/4/2017  0.02189       NaN     NaN         NaN               NaN
# 4      10/5/2017  0.02152       NaN     NaN         NaN               NaN
# ...          ...      ...       ...     ...         ...               ...
# 1543  12/22/2021  1.32800     1.364   27.28      0.5367            0.3185
# 1544  12/23/2021  1.47400     1.470   28.37      0.5949            0.3290
# 1545  12/24/2021  1.39200     1.575   26.87      0.6278            0.3108
# 1546  12/25/2021  1.45400     1.576   29.68      0.6436            0.3150
# 1547  12/26/2021  1.43800     1.623   31.35      0.6154            0.3182
#
# [1548 rows x 6 columns]

# %%
Pos1 = Pos1.dropna()

# %%
##   -------------------------------AFD TEST: pos1------------------------------------

# %%
Pos1
# Out:
#         datetime  cardano  algorand  cosmos  crypto_com  hedera_hashgraph
# 719    9/20/2019  0.05254    0.3207   3.189     0.03996           0.05257
# 720    9/21/2019  0.05202    0.3157   3.065     0.03856           0.04787
# 721    9/22/2019  0.04909    0.3005   2.909     0.03578           0.03940
# 722    9/23/2019  0.04623    0.2674   2.572     0.03771           0.03783
# 723    9/24/2019  0.03760    0.1929   2.234     0.03258           0.02961
# ...          ...      ...       ...     ...         ...               ...
# 1543  12/22/2021  1.32800    1.3640  27.280     0.53670           0.31850
# 1544  12/23/2021  1.47400    1.4700  28.370     0.59490           0.32900
# 1545  12/24/2021  1.39200    1.5750  26.870     0.62780           0.31080
# 1546  12/25/2021  1.45400    1.5760  29.680     0.64360           0.31500
# 1547  12/26/2021  1.43800    1.6230  31.350     0.61540           0.31820
#
# [829 rows x 6 columns]

# %%
cardano_daydata = Pos1.loc[:, 'cardano'].values

# %%
result = adfuller(cardano_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, cardano in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {cardano}')
# Out:
# ADF Statistic: -1.220258385328509
# n_lags: 0.66482092384529
# p-value: 0.66482092384529
# Critial Values:
#    1%, -3.4384690549764856
# Critial Values:
#    5%, -2.8651236651346306
# Critial Values:
#    10%, -2.568678262976669

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(cardano_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Cardano')
# Out:
# Text(0.5, 1.0, 'Cardano')

# %%
algorand_daydata =   Pos1.loc[:, 'algorand'].values

# %%
result = adfuller(algorand_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, algorand in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {algorand}')
# Out:
# ADF Statistic: -0.6846808073084919
# n_lags: 0.8506777514791481
# p-value: 0.8506777514791481
# Critial Values:
#    1%, -3.4384289321263126
# Critial Values:
#    5%, -2.865105979079729
# Critial Values:
#    10%, -2.568668841575869

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(algorand_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('algorand_daydata')
# Out:
# Text(0.5, 1.0, 'algorand_daydata')

# %%
cosmos_daydata = Pos1.loc[:, 'cosmos'].values

# %%
result = adfuller(cosmos_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, cosmos in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {cosmos}')
# Out:
# ADF Statistic: -0.6730459111248511
# n_lags: 0.8536082783005601
# p-value: 0.8536082783005601
# Critial Values:
#    1%, -3.4384389256151358
# Critial Values:
#    5%, -2.8651103842072048
# Critial Values:
#    10%, -2.568671188193778

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(cosmos_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('cosmos_daydata')
# Out:
# Text(0.5, 1.0, 'cosmos_daydata')

# %%
crypto_com_daydata = Pos1.loc[:, 'crypto_com'].values

# %%
result = adfuller(crypto_com_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, crypto_com in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {crypto_com}')
# Out:
# ADF Statistic: 0.25400059824438165
# n_lags: 0.9751327913956429
# p-value: 0.9751327913956429
# Critial Values:
#    1%, -3.4383892038884722
# Critial Values:
#    5%, -2.8650884667384955
# Critial Values:
#    10%, -2.568659512747501

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(crypto_com_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('crypto_com')
# Out:
# Text(0.5, 1.0, 'crypto_com')

# %%
hedera_hashgraph_daydata = Pos1.loc[:, 'hedera_hashgraph'].values

# %%
result = adfuller(hedera_hashgraph_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, hedera_hashgraph in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {hedera_hashgraph}')
# Out:
# ADF Statistic: -0.9235757213610224
# n_lags: 0.7801094906272352
# p-value: 0.7801094906272352
# Critial Values:
#    1%, -3.4383303387882793
# Critial Values:
#    5%, -2.8650625183820577
# Critial Values:
#    10%, -2.5686456901154977

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(hedera_hashgraph_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('hedera_hashgraph_daydata')
# Out:
# Text(0.5, 1.0, 'hedera_hashgraph_daydata')

# %%
##             ---------------Engle-Granger Test Pos1--------------------- from 9/20/2019 to 11/5/2020

# %%
Pos1
# Out:
#         datetime  cardano  algorand  cosmos  crypto_com  hedera_hashgraph
# 719    9/20/2019  0.05254    0.3207   3.189     0.03996           0.05257
# 720    9/21/2019  0.05202    0.3157   3.065     0.03856           0.04787
# 721    9/22/2019  0.04909    0.3005   2.909     0.03578           0.03940
# 722    9/23/2019  0.04623    0.2674   2.572     0.03771           0.03783
# 723    9/24/2019  0.03760    0.1929   2.234     0.03258           0.02961
# ...          ...      ...       ...     ...         ...               ...
# 1543  12/22/2021  1.32800    1.3640  27.280     0.53670           0.31850
# 1544  12/23/2021  1.47400    1.4700  28.370     0.59490           0.32900
# 1545  12/24/2021  1.39200    1.5750  26.870     0.62780           0.31080
# 1546  12/25/2021  1.45400    1.5760  29.680     0.64360           0.31500
# 1547  12/26/2021  1.43800    1.6230  31.350     0.61540           0.31820
#
# [829 rows x 6 columns]

# %%
df = pd.DataFrame(Pos1, columns= ['cardano','algorand'])
X = df["cardano"]
y = df["algorand"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -2.813377
# p-value                                                               0.161466
# Critical Values 1%,5%,10%    [-3.909715835200355, -3.343519299925319, -3.04...
# dtype: object

# %%
df = pd.DataFrame(Pos1, columns= ['cardano','cosmos'])
X = df["cardano"]
y = df["cosmos"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -2.173572
# p-value                                                               0.438031
# Critical Values 1%,5%,10%    [-3.909715835200355, -3.343519299925319, -3.04...
# dtype: object

# %%
df = pd.DataFrame(Pos1, columns= ['cardano','crypto_com'])
X = df["cardano"]
y = df["crypto_com"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -0.512419
# p-value                                                               0.963436
# Critical Values 1%,5%,10%    [-3.909715835200355, -3.343519299925319, -3.04...
# dtype: object

# %%
df = pd.DataFrame(Pos1, columns= ['cardano','hedera_hashgraph'])
X = df["cardano"]
y = df["hedera_hashgraph"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -3.916004
# p-value                                                               0.009426
# Critical Values 1%,5%,10%    [-3.909715835200355, -3.343519299925319, -3.04...
# dtype: object

# %%
## ----------------------------ADF Test: POS2-----------------------------------near	PayProtocol	Oasis_labs	terraUSD

# %%
Pos2 = POS.loc[:, ['datetime', 'near', 'PayProtocol', 'Oasis_labs', 'terraUSD']]
Pos2
# Out:
#         datetime   near  PayProtocol  Oasis_labs  terraUSD
# 0      10/1/2017    NaN          NaN         NaN       NaN
# 1      10/2/2017    NaN          NaN         NaN       NaN
# 2      10/3/2017    NaN          NaN         NaN       NaN
# 3      10/4/2017    NaN          NaN         NaN       NaN
# 4      10/5/2017    NaN          NaN         NaN       NaN
# ...          ...    ...          ...         ...       ...
# 1543  12/22/2021  10.82        1.377      0.2700     1.003
# 1544  12/23/2021  13.73        1.421      0.3177     1.001
# 1545  12/24/2021  14.94        1.415      0.3047     1.001
# 1546  12/25/2021  15.20        1.401      0.3417     1.001
# 1547  12/26/2021  14.88        1.417      0.3462     1.001
#
# [1548 rows x 5 columns]

# %%
Pos2 = Pos2.dropna()
Pos2
# Out:
#         datetime     near  PayProtocol  Oasis_labs  terraUSD
# 1158   12/2/2020   1.1790       0.1633     0.03616     1.004
# 1159   12/3/2020   1.1560       0.1634     0.03854     1.002
# 1160   12/4/2020   1.1030       0.1591     0.03953     1.000
# 1161   12/5/2020   1.1140       0.1623     0.04512     1.002
# 1164   12/8/2020   0.9329       0.1659     0.05346     1.002
# ...          ...      ...          ...         ...       ...
# 1543  12/22/2021  10.8200       1.3770     0.27000     1.003
# 1544  12/23/2021  13.7300       1.4210     0.31770     1.001
# 1545  12/24/2021  14.9400       1.4150     0.30470     1.001
# 1546  12/25/2021  15.2000       1.4010     0.34170     1.001
# 1547  12/26/2021  14.8800       1.4170     0.34620     1.001
#
# [388 rows x 5 columns]

# %%
near_daydata = Pos2.loc[:, 'near'].values

# %%
result = adfuller(near_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, near in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {near}')
# Out:
# ADF Statistic: -0.24913243200136256
# n_lags: 0.9324061099586474
# p-value: 0.9324061099586474
# Critial Values:
#    1%, -3.4476305904172904
# Critial Values:
#    5%, -2.869155980820355
# Critial Values:
#    10%, -2.570827146203181

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(near_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('near_daydata')
# Out:
# Text(0.5, 1.0, 'near_daydata')

# %%
PayProtocol_daydata = Pos2.loc[:, 'PayProtocol'].values

# %%
result = adfuller(PayProtocol_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, PayProtocol in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {PayProtocol}')
# Out:
# ADF Statistic: -2.242121032189161
# n_lags: 0.19131451038820235
# p-value: 0.19131451038820235
# Critial Values:
#    1%, -3.4474498334928687
# Critial Values:
#    5%, -2.8690765390453703
# Critial Values:
#    10%, -2.570784795075055

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(PayProtocol_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('PayProtocol_daydata')
# Out:
# Text(0.5, 1.0, 'PayProtocol_daydata')

# %%
Oasis_labs_daydata = Pos2.loc[:, 'Oasis_labs'].values

# %%
result = adfuller(Oasis_labs_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, Oasis_labs in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {Oasis_labs}')
# Out:
# ADF Statistic: -0.9882148287596108
# n_lags: 0.7575383658734851
# p-value: 0.7575383658734851
# Critial Values:
#    1%, -3.447405233596701
# Critial Values:
#    5%, -2.8690569369014605
# Critial Values:
#    10%, -2.5707743450830893

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(Oasis_labs_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('Oasis_labs_daydata')
# Out:
# Text(0.5, 1.0, 'Oasis_labs_daydata')

# %%
terraUSD_daydata = Pos2.loc[:, 'terraUSD'].values

# %%
result = adfuller(terraUSD_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime, terraUSD in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {terraUSD}')
# Out:
# ADF Statistic: -2.9866700795223773
# n_lags: 0.036158138414143746
# p-value: 0.036158138414143746
# Critial Values:
#    1%, -3.448003816652923
# Critial Values:
#    5%, -2.86931999731073
# Critial Values:
#    10%, -2.5709145866785503

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(terraUSD_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('terraUSD')
# Out:
# Text(0.5, 1.0, 'terraUSD')

# %%
##-------------------------Engle-Granger Test-------------------------------------

# %%
df = pd.DataFrame(Pos2, columns= ['near','PayProtocol'])
X = df["near"]
y = df["PayProtocol"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -2.403994
# p-value                                                               0.322966
# Critical Values 1%,5%,10%    [-3.924815546685523, -3.3518822875212297, -3.0...
# dtype: object

# %%
df = pd.DataFrame(Pos2, columns= ['near','Oasis_labs'])
X = df["near"]
y = df["Oasis_labs"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -3.869327
# p-value                                                               0.010929
# Critical Values 1%,5%,10%    [-3.924815546685523, -3.3518822875212297, -3.0...
# dtype: object

# %%
df = pd.DataFrame(Pos2, columns= ['near','terraUSD'])
X = df["near"]
y = df["terraUSD"]
from statsmodels.tsa.stattools import coint
print('Results of Engle-Granger Test:')
egtest = coint(y, X, method='aeg', autolag='AIC')
egoutput = pd.Series(egtest[0:3], index=['Test Statistic','p-value','Critical Values 1%,5%,10%'])
print (egoutput)
# Out:
# Results of Engle-Granger Test:
# Test Statistic                                                       -3.001707
# p-value                                                                 0.1098
# Critical Values 1%,5%,10%    [-3.924815546685523, -3.3518822875212297, -3.0...
# dtype: object

# %%
##       ---------------------ADF Test----------------POS3----internet_computer	avalanche	anchor_protocol

# %%
Pos3 = POS.loc[:, ['datetime', 'internet_computer', 'avalanche', 'anchor_protocol']]
Pos3
# Out:
#         datetime  internet_computer  avalanche  anchor_protocol
# 0      10/1/2017                NaN        NaN              NaN
# 1      10/2/2017                NaN        NaN              NaN
# 2      10/3/2017                NaN        NaN              NaN
# 3      10/4/2017                NaN        NaN              NaN
# 4      10/5/2017                NaN        NaN              NaN
# ...          ...                ...        ...              ...
# 1543  12/22/2021              23.32     116.67            3.717
# 1544  12/23/2021              26.96     121.36            3.751
# 1545  12/24/2021              27.61     114.89            3.986
# 1546  12/25/2021              27.28     115.01            4.040
# 1547  12/26/2021              26.37     112.11            4.007
#
# [1548 rows x 4 columns]

# %%
Pos3 = Pos3.dropna()
Pos3
# Out:
#         datetime  internet_computer  avalanche  anchor_protocol
# 1317   5/10/2021             426.98      34.71            5.400
# 1318   5/11/2021             363.71      36.81            5.420
# 1319   5/12/2021             258.41      32.97            5.635
# 1320   5/13/2021             301.36      35.06            5.367
# 1321   5/14/2021             304.46      37.02            5.403
# ...          ...                ...        ...              ...
# 1543  12/22/2021              23.32     116.67            3.717
# 1544  12/23/2021              26.96     121.36            3.751
# 1545  12/24/2021              27.61     114.89            3.986
# 1546  12/25/2021              27.28     115.01            4.040
# 1547  12/26/2021              26.37     112.11            4.007
#
# [231 rows x 4 columns]

# %%
internet_computer_daydata = Pos3.loc[:, 'internet_computer'].values

# %%
result = adfuller(internet_computer_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime,internet_computer in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {internet_computer}')
# Out:
# ADF Statistic: -3.2220278548785704
# n_lags: 0.01874450671476917
# p-value: 0.01874450671476917
# Critial Values:
#    1%, -3.461136478222043
# Critial Values:
#    5%, -2.875078880098608
# Critial Values:
#    10%, -2.5739861168199027

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(internet_computer_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('internet_computer')
# Out:
# Text(0.5, 1.0, 'internet_computer')

# %%
avalanche_daydata = Pos3.loc[:, 'avalanche'].values

# %%
result = adfuller(avalanche_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime,avalanche in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {avalanche}')
# Out:
# ADF Statistic: -0.2657503255084668
# n_lags: 0.9302169875953439
# p-value: 0.9302169875953439
# Critial Values:
#    1%, -3.459105583381277
# Critial Values:
#    5%, -2.8741898504150574
# Critial Values:
#    10%, -2.5735117958412097

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(avalanche_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('avalanche_daydata')
# Out:
# Text(0.5, 1.0, 'avalanche_daydata')

# %%
anchor_protocol_daydata = Pos3.loc[:, 'anchor_protocol'].values

# %%
result = adfuller(anchor_protocol_daydata, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for datetime,anchor_protocol in result[4].items():
    print('Critial Values:')
    print(f'   {datetime}, {anchor_protocol}')
# Out:
# ADF Statistic: -3.035965797961807
# n_lags: 0.03166944003514192
# p-value: 0.03166944003514192
# Critial Values:
#    1%, -3.459105583381277
# Critial Values:
#    5%, -2.8741898504150574
# Critial Values:
#    10%, -2.5735117958412097

# %%
fig, axes = plt.subplots(figsize=(10,7))
plt.plot(anchor_protocol_daydata);
plt.xlabel('Time')
plt.ylabel('Price')
plt.title('anchor_protocol')
# Out:
# Text(0.5, 1.0, 'anchor_protocol')

# %%
# Cointegration among these three cryptocurriences are not possible because internet_compute and anchor_protocol show 
#stationary behavior although p value of avalanche show it is non-stationary.
